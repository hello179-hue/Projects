# %%
import pandas as pd 
import numpy as np 
import warnings as w
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.chdir(r'C:\Users\srish\OneDrive\Desktop\Project\Dataset')

# %%
df = pd.read_csv(r'C:\Users\srish\OneDrive\Desktop\Project\Dataset\final_dataset.csv')

# %%
df.head(5)
# Out:
#    Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0     1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1     2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2     3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3     4      1  2021               0     1   89.55  132.08  153.98  10.42
# 4     5      1  2021               0     2   54.06   55.54  122.66   9.70
#
#      CO  Ozone  AQI
# 0  2.77  43.19  462
# 1  2.60  16.43  482
# 2  1.40  44.29  263
# 3  1.01  49.19  207
# 4  0.64  48.88  149

# %%
df['Day'] = df['Date']

# %%
df.drop(columns='Date',inplace=True)

# %%
df['proper_date'] = pd.to_datetime(df[['Year','Month','Day']])

df = df.sort_values('proper_date')

# %%
df.head(5)
# Out:
#    Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2    CO  \
# 0      1  2021               0     5  408.80  442.42  160.61  12.95  2.77
# 1      1  2021               0     6  404.04  561.95   52.85   5.18  2.60
# 2      1  2021               1     7  225.07  239.04  170.95  10.93  1.40
# 3      1  2021               0     1   89.55  132.08  153.98  10.42  1.01
# 4      1  2021               0     2   54.06   55.54  122.66   9.70  0.64
#
#    Ozone  AQI  Day proper_date
# 0  43.19  462    1  2021-01-01
# 1  16.43  482    2  2021-01-02
# 2  44.29  263    3  2021-01-03
# 3  49.19  207    4  2021-01-04
# 4  48.88  149    5  2021-01-05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Month           1461 non-null   int64
#  1   Year            1461 non-null   int64
#  2   Holidays_Count  1461 non-null   int64
#  3   Days            1461 non-null   int64
#  4   PM2.5           1461 non-null   float64
#  5   PM10            1461 non-null   float64
#  6   NO2             1461 non-null   float64
#  7   SO2             1461 non-null   float64
#  8   CO              1461 non-null   float64
#  9   Ozone           1461 non-null   float64
#  10  AQI             1461 non-null   int64
#  11  Day             1461 non-null   int64
#  12  proper_date     1461 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(6)
# memory usage: 148.5 KB

# %%
df.columns
# Out:
# Index(['Month', 'Year', 'Holidays_Count', 'Days', 'PM2.5', 'PM10', 'NO2',
#        'SO2', 'CO', 'Ozone', 'AQI', 'Day', 'proper_date'],
#       dtype='object')

# %%
df.describe()
# Out:
#              Month         Year  Holidays_Count         Days        PM2.5  \
# count  1461.000000  1461.000000     1461.000000  1461.000000  1461.000000
# mean      6.522930  2022.501027        0.189596     4.000684    90.774538
# min       1.000000  2021.000000        0.000000     1.000000     0.050000
# 25%       4.000000  2022.000000        0.000000     2.000000    41.280000
# 50%       7.000000  2023.000000        0.000000     4.000000    72.060000
# 75%      10.000000  2024.000000        0.000000     6.000000   118.500000
# max      12.000000  2024.000000        1.000000     7.000000  1000.000000
# std       3.449884     1.118723        0.392116     2.001883    71.650579
#
#               PM10          NO2          SO2           CO        Ozone  \
# count  1461.000000  1461.000000  1461.000000  1461.000000  1461.000000
# mean    218.219261    37.184921    20.104921     1.025832    36.338871
# min       9.690000     2.160000     1.210000     0.270000     2.700000
# ...

# %%
df.nunique()
# Out:
# Month               12
# Year                 4
# Holidays_Count       2
# Days                 7
# PM2.5             1391
# PM10              1436
# NO2               1308
# SO2               1180
# CO                 240
# Ozone             1264
# AQI                403
# Day                 31
# proper_date       1461
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Month             0
# Year              0
# Holidays_Count    0
# Days              0
# PM2.5             0
# PM10              0
# NO2               0
# SO2               0
# CO                0
# Ozone             0
# AQI               0
# Day               0
# proper_date       0
# dtype: int64

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
sns.histplot(df['AQI'], bins=30, kde = True, color="red")
plt.title('AQI Histogram')
plt.xlabel('AQI')
plt.ylabel('Frequency')
plt.show()

# %%
pollutants = ['PM2.5', 'PM10', 'NO2', 'SO2', 'CO', 'Ozone']
df[pollutants].hist(bins=30, figsize=(15,8))
plt.suptitle('Pollutants Distribution')
plt.show()
